# %% [markdown]
# ## 3. Graicos com plotly

# %%
#Carregando bibliotecas

import pandas as pandas
from bdconfig import cria_conexao, carrega_tabela
import plotly.graph_objects as go

# %%
#Conxão com banco de dados

bd = '../dados/clima.db'
con = cria_conexao(bd)

df = carrega_tabela("JoaoPessoa",con = con, clima = True)
con.close()


df.head()
# Out:
#                      TempBulboSeco  TempBulboUmido  UmidadeRelativa  \
# Horario
# 2008-01-01 00:00:00           26.8            22.6             68.0
# 2008-01-01 12:00:00           29.4            23.3             58.0
# 2008-01-01 18:00:00           29.6            23.5             59.0
# 2008-02-01 00:00:00           26.6            22.2             69.0
# 2008-02-01 12:00:00           29.8            23.9             61.0
#
#                      PressaoAtmEstacao DirecaoVento  VelocidadeVento  \
# Horario
# 2008-01-01 00:00:00             1012.1           14              3.3
# 2008-01-01 12:00:00             1012.7           14              3.5
# 2008-01-01 18:00:00             1011.2           14              3.3
# 2008-02-01 00:00:00             1012.8           14              2.6
# 2008-02-01 12:00:00             1013.3           14              3.3
#
#                      Nebulosidade
# Horario
# 2008-01-01 00:00:00           3.0
# 2008-01-01 12:00:00           4.0
# 2008-01-01 18:00:00           3.0
# 2008-02-01 00:00:00           4.0
# 2008-02-01 12:00:00           3.0

# %%
fig = go.Figure([go.Scatter(x=df['2008'].index, y=df['TempBulboSeco']['2008'])])
fig.show()

# %%
df['2008']
# Out:
#                      TempBulboSeco  TempBulboUmido  UmidadeRelativa  \
# Horario
# 2008-01-01 00:00:00           26.8            22.6             68.0
# 2008-01-01 12:00:00           29.4            23.3             58.0
# 2008-01-01 18:00:00           29.6            23.5             59.0
# 2008-02-01 00:00:00           26.6            22.2             69.0
# 2008-02-01 12:00:00           29.8            23.9             61.0
# ...                            ...             ...              ...
# 2008-12-30 12:00:00           29.4            23.3             58.0
# 2008-12-30 18:00:00           28.6            23.3             65.0
# 2008-12-31 00:00:00           27.0            22.7             69.0
# 2008-12-31 12:00:00           29.6            23.9             62.0
# 2008-12-31 18:00:00           30.0            23.9             61.0
#
#                      PressaoAtmEstacao DirecaoVento  VelocidadeVento  \
# Horario
# 2008-01-01 00:00:00             1012.1           14              3.3
# 2008-01-01 12:00:00             1012.7           14              3.5
# 2008-01-01 18:00:00             1011.2           14              3.3
# 2008-02-01 00:00:00             1012.8           14              2.6
# 2008-02-01 12:00:00             1013.3           14              3.3
# ...                                ...          ...              ...
# 2008-12-30 12:00:00             1012.8           14              4.0
# 2008-12-30 18:00:00             1010.2            9              2.8
# 2008-12-31 00:00:00             1012.3            9              2.3
# 2008-12-31 12:00:00             1013.3           14              3.0
# 2008-12-31 18:00:00             1011.1           14              3.0
#
#                      Nebulosidade
# Horario
# 2008-01-01 00:00:00           3.0
# 2008-01-01 12:00:00           4.0
# 2008-01-01 18:00:00           3.0
# 2008-02-01 00:00:00           4.0
# 2008-02-01 12:00:00           3.0
# ...                           ...
# 2008-12-30 12:00:00           6.0
# 2008-12-30 18:00:00           9.0
# 2008-12-31 00:00:00           5.0
# 2008-12-31 12:00:00           4.0
# 2008-12-31 18:00:00           2.0
#
# [1091 rows x 7 columns]
